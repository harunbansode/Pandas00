# %% [markdown]
# <a href="https://colab.research.google.com/github/harunbansode/Pandas00/blob/main/Pandas00.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame([[1, 2, 3], [4, 5, 6], [7, 8, 9]], columns=['A', 'B', 'C'])

# %%
df.head()
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df.shape
# Out:
# (3, 3)

# %% [markdown]
# **Head is used for Top to Bottom**

# %%
df.head(1)
# Out:
#    A  B  C
# 0  1  2  3

# %%
df.head(2)
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %%
df.head(3)
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %% [markdown]
# **Tail is used for Bottom to Top**

# %%
df.tail(1)
# Out:
#    A  B  C
# 2  7  8  9

# %%
df.tail(2)
# Out:
#    A  B  C
# 1  4  5  6
# 2  7  8  9

# %%
df.tail(3)
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %% [markdown]
# **For Headers**

# %%
df.columns
# Out:
# Index(['A', 'B', 'C'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.index.tolist()
# Out:
# [0, 1, 2]

# %% [markdown]
# **Setting up default index**

# %%
df = pd.DataFrame([[1, 2, 3], [4, 5, 6], [7, 8, 9]], columns=['A', 'B', 'C'], index=['x', 'y', 'z'])

# %%
df
# Out:
#    A  B  C
# x  1  2  3
# y  4  5  6
# z  7  8  9

# %%
df.index
# Out:
# Index(['x', 'y', 'z'], dtype='object')

# %%
df.index.tolist()
# Out:
# ['x', 'y', 'z']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, x to z
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
#  2   C       3 non-null      int64
# dtypes: int64(3)
# memory usage: 204.0+ bytes

# %%
df.describe()
# Out:
#          A    B    C
# count  3.0  3.0  3.0
# mean   4.0  5.0  6.0
# std    3.0  3.0  3.0
# min    1.0  2.0  3.0
# 25%    2.5  3.5  4.5
# 50%    4.0  5.0  6.0
# 75%    5.5  6.5  7.5
# max    7.0  8.0  9.0

# %%
df.nunique()
# Out:
# A    3
# B    3
# C    3
# dtype: int64

# %%
df['A'].nunique()
# Out:
# 3

# %%
df.size
# Out:
# 9

# %%
coffee = pd.read_csv('/coffee.csv')

# %%
# chai = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/warmup-data/coffee.csv')

# %%
# chai

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
results = pd.read_parquet('/results.parquet')

# %%
results
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                    None        Slalom, Women (Olympic)
#
# ...

# %%
results.columns.tolist()
# Out:
# ['year',
#  'type',
#  'discipline',
#  'event',
#  'as',
#  'athlete_id',
#  'noc',
#  'team',
#  'place',
#  'tied',
#  'medal']

# %%
results.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA             None   17.0   True  None
# 1           1  FRA   Jean Montariol    NaN  False  None
# 2           1  FRA             None   32.0   True  None
# 3           1  FRA  Jeanne Vaussard    8.0   True  None
# 4           1  FRA  Jacques Brugnon    4.0  False  None

# %%
olympics_data = pd.read_excel('/olympics-data.xlsx', sheet_name = "results")

# %%
olympics_data.head()
# Out:
#      year    type discipline                     event                     as  \
# 0  1912.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 1  1912.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
# 2  1920.0  Summer     Tennis    Singles, Men (Olympic)  Jean-François Blanchy
# 3  1920.0  Summer     Tennis  Doubles, Mixed (Olympic)  Jean-François Blanchy
# 4  1920.0  Summer     Tennis    Doubles, Men (Olympic)  Jean-François Blanchy
#
#    athlete_id  noc             team  place   tied medal
# 0           1  FRA              NaN   17.0   True   NaN
# 1           1  FRA   Jean Montariol    NaN  False   NaN
# 2           1  FRA              NaN   32.0   True   NaN
# 3           1  FRA  Jeanne Vaussard    8.0   True   NaN
# 4           1  FRA  Jacques Brugnon    4.0  False   NaN

# %%
bios = pd.read_csv('/bios.csv')

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
coffee.loc[[1, 2, 5]]
# Out:
#          Day Coffee Type  Units Sold
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 5  Wednesday       Latte          25

# %%
coffee.loc[:, ['Day', 'Coffee Type']]
# Out:
#           Day Coffee Type
# 0      Monday    Espresso
# 1      Monday       Latte
# 2     Tuesday    Espresso
# 3     Tuesday       Latte
# 4   Wednesday    Espresso
# 5   Wednesday       Latte
# 6    Thursday    Espresso
# 7    Thursday       Latte
# 8      Friday    Espresso
# 9      Friday       Latte
# 10   Saturday    Espresso
# 11   Saturday       Latte
# 12     Sunday    Espresso
# 13     Sunday       Latte

# %%
coffee.loc[8:12, ['Day', 'Units Sold']]
# Out:
#          Day  Units Sold
# 8     Friday          45
# 9     Friday          35
# 10  Saturday          45
# 11  Saturday          35
# 12    Sunday          45

# %%
coffee.iloc[0:5, [0,2]]
# Out:
#          Day  Units Sold
# 0     Monday          25
# 1     Monday          15
# 2    Tuesday          30
# 3    Tuesday          20
# 4  Wednesday          35

# %%
# coffee.index = coffee['Day']

# %%
# coffee.loc[['Sunday', 'Saturday']]

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
# coffee.loc[1:4, 'Units Sold'] = 10

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
# coffee.iat[0,0]

# %%
# coffee.at[0, "Coffee Type"]

# %%
# coffee['Coffee Type']

# %%
coffee.sort_values('Coffee Type', ascending=True)
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 2     Tuesday    Espresso          30
# 4   Wednesday    Espresso          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 5   Wednesday       Latte          25
# 7    Thursday       Latte          30
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35

# %%
coffee.sort_values(["Units Sold", "Coffee Type"], ascending=[0, 1])
# Out:
#           Day Coffee Type  Units Sold
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45
# 6    Thursday    Espresso          40
# 4   Wednesday    Espresso          35
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35
# 2     Tuesday    Espresso          30
# 7    Thursday       Latte          30
# 0      Monday    Espresso          25
# 5   Wednesday       Latte          25
# 3     Tuesday       Latte          20
# 1      Monday       Latte          15

# %%
bios
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios.loc[bios['height_cm'] > 215, ['name', 'born_city']]
# Out:
#                          name               born_city
# 5089       Viktor Pankrashkin         Moskva (Moscow)
# 5583     Paulinho Villas Boas               São Paulo
# 5673           Gunther Behnke              Leverkusen
# 5716                 Uwe Blab        München (Munich)
# 5781           Tommy Burleson               Crossnore
# 5796            Andy Campbell               Melbourne
# 6223              Lars Hansen  København (Copenhagen)
# 6270              Hu Zhangbao                     NaN
# 6409         Sergey Kovalenko                     NaN
# 6420            Jānis Krūmiņš                   Cēsis
# 6504              Luc Longley               Melbourne
# 6722         Shaquille O'Neal                  Newark
# 6937           David Robinson                Key West
# 6978          Arvydas Sabonis                  Kaunas
# 7074           Paulo da Silva               São Paulo
# 7188       Vladimir Tkachenko               Golovinka
# ...

# %%
bios[bios['height_cm'] > 215][['name', 'born_city']]
# Out:
#                          name               born_city
# 5089       Viktor Pankrashkin         Moskva (Moscow)
# 5583     Paulinho Villas Boas               São Paulo
# 5673           Gunther Behnke              Leverkusen
# 5716                 Uwe Blab        München (Munich)
# 5781           Tommy Burleson               Crossnore
# 5796            Andy Campbell               Melbourne
# 6223              Lars Hansen  København (Copenhagen)
# 6270              Hu Zhangbao                     NaN
# 6409         Sergey Kovalenko                     NaN
# 6420            Jānis Krūmiņš                   Cēsis
# 6504              Luc Longley               Melbourne
# 6722         Shaquille O'Neal                  Newark
# 6937           David Robinson                Key West
# 6978          Arvydas Sabonis                  Kaunas
# 7074           Paulo da Silva               São Paulo
# 7188       Vladimir Tkachenko               Golovinka
# ...

# %%
bios[(bios['height_cm'] > 215) & (bios['born_country'] == 'USA')]
# Out:
#         athlete_id              name   born_date  born_city     born_region  \
# 5781          5804    Tommy Burleson  1952-02-24  Crossnore  North Carolina
# 6722          6755  Shaquille O'Neal  1972-03-06     Newark      New Jersey
# 6937          6972    David Robinson  1965-08-06   Key West         Florida
# 123850      126093    Tyson Chandler  1982-10-02    Hanford      California
#
#        born_country            NOC  height_cm  weight_kg died_date
# 5781            USA  United States      223.0      102.0       NaN
# 6722            USA  United States      216.0      137.0       NaN
# 6937            USA  United States      216.0      107.0       NaN
# 123850          USA  United States      216.0      107.0       NaN

# %%
bios[bios['name'].str.contains('harun|vivek', case=False)]
# Out:
#         athlete_id               name   born_date        born_city  \
# 19167        19302        Vivek Singh  1967-08-01         Varanasi
# 22593        22763      Harunobu Deno  1969-08-28              NaN
# 42798        43123         John Harun  1948-06-24         Machakos
# 48264        48617        Mika Haruna  1978-06-14              NaN
# 59884        60312        Harun Doğan  1976-01-01    Kahramanmaraş
# 63220        63690        Harun Ülman  1900-07-11              NaN
# 93554        94306      Haruna Hosoya  1973-04-23        Kawanishi
# 116094      117475     Haruna Fukuoka  1984-01-25        Tokushima
# 119153      120939  Haruna Sakakibara  1994-03-11              Iyo
# 125664      128009    Haruna Yoneyama  1991-11-07         Shizunai
# 131609      134419    Ayyasamy Dharun  1996-12-31  Chinneripalayam
# 134374      137434    Haruna Ishikawa  1994-07-20         Kanazawa
# 134417      137480   Haruna Matsumoto  1993-07-26          Sapporo
# ...

# %%
bios[bios['born_country'].isin(['USA', 'GBR', 'FRA', 'TUR']) & (bios['name'].str.startswith('Harun'))]
# Out:
#        athlete_id         name   born_date      born_city    born_region  \
# 59884       60312  Harun Doğan  1976-01-01  Kahramanmaraş  Kahramanmaraş
#
#       born_country      NOC  height_cm  weight_kg died_date
# 59884          TUR  Türkiye      165.0       58.0       NaN

# %%
bios.query('born_city == "Jersey City" & born_country == "USA"')
# Out:
#         athlete_id               name   born_date    born_city born_region  \
# 16442        16558        Don Sheldon  1930-05-26  Jersey City  New Jersey
# 20238        20382    Bill Boddington  1910-11-22  Jersey City  New Jersey
# 20871        21018     Evelyn Terhune  1932-07-21  Jersey City  New Jersey
# 23526        23708     Ernest Gignoux  1874-08-26  Jersey City  New Jersey
# 23550        23733         Marty Lang  1949-05-20  Jersey City  New Jersey
# 31110        31346         Don Holder  1928-09-29  Jersey City  New Jersey
# 32772        33018         Bob Sparks  1947-09-11  Jersey City  New Jersey
# 44369        44710        Bill Libbey  1855-03-27  Jersey City  New Jersey
# 50741        51100     Lisa Lindstrom  1912-08-07  Jersey City  New Jersey
# 60362        60795   Alexander Weyand  1892-01-10  Jersey City  New Jersey
# 60368        60801   Henry Wittenberg  1918-09-18  Jersey City  New Jersey
# ...

# %%
bios.query('born_city == "Edison" & born_country == "USA"')
# Out:
#         athlete_id             name   born_date born_city born_region  \
# 113704      115003  Erison Hurtault  1984-12-29    Edison  New Jersey
#
#        born_country       NOC  height_cm  weight_kg died_date
# 113704          USA  Dominica      178.0       78.0       NaN

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
coffee['price'] = 5.99

# %%
coffee['new_price'] = np.where(coffee['Coffee Type'] == 'Espresso', 3.99, 5.99)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  new_price
# 0      Monday    Espresso          25   5.99       3.99
# 1      Monday       Latte          15   5.99       5.99
# 2     Tuesday    Espresso          30   5.99       3.99
# 3     Tuesday       Latte          20   5.99       5.99
# 4   Wednesday    Espresso          35   5.99       3.99
# 5   Wednesday       Latte          25   5.99       5.99
# 6    Thursday    Espresso          40   5.99       3.99
# 7    Thursday       Latte          30   5.99       5.99
# 8      Friday    Espresso          45   5.99       3.99
# 9      Friday       Latte          35   5.99       5.99
# 10   Saturday    Espresso          45   5.99       3.99
# 11   Saturday       Latte          35   5.99       5.99
# 12     Sunday    Espresso          45   5.99       3.99
# 13     Sunday       Latte          35   5.99       5.99

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       3.99
# 1      Monday       Latte          15       5.99
# 2     Tuesday    Espresso          30       3.99
# 3     Tuesday       Latte          20       5.99
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35       5.99

# %%
# coffee.drop(columns = ['price'])

# %%
# coffee.drop(columns = ['price'], inplace=True)
# coffee

# %%
# coffee = coffee[['Coffee Type', 'Units Sold']]
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       3.99
# 1      Monday       Latte          15       5.99
# 2     Tuesday    Espresso          30       3.99
# 3     Tuesday       Latte          20       5.99
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35       5.99

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price
# 0      Monday    Espresso          25       3.99
# 1      Monday       Latte          15       5.99
# 2     Tuesday    Espresso          30       3.99
# 3     Tuesday       Latte          20       5.99
# 4   Wednesday    Espresso          35       3.99
# 5   Wednesday       Latte          25       5.99
# 6    Thursday    Espresso          40       3.99
# 7    Thursday       Latte          30       5.99
# 8      Friday    Espresso          45       3.99
# 9      Friday       Latte          35       5.99
# 10   Saturday    Espresso          45       3.99
# 11   Saturday       Latte          35       5.99
# 12     Sunday    Espresso          45       3.99
# 13     Sunday       Latte          35       5.99

# %%
coffee['revenue'] = coffee['Units Sold'] * coffee['new_price']

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  new_price  revenue
# 0      Monday    Espresso          25       3.99    99.75
# 1      Monday       Latte          15       5.99    89.85
# 2     Tuesday    Espresso          30       3.99   119.70
# 3     Tuesday       Latte          20       5.99   119.80
# 4   Wednesday    Espresso          35       3.99   139.65
# 5   Wednesday       Latte          25       5.99   149.75
# 6    Thursday    Espresso          40       3.99   159.60
# 7    Thursday       Latte          30       5.99   179.70
# 8      Friday    Espresso          45       3.99   179.55
# 9      Friday       Latte          35       5.99   209.65
# 10   Saturday    Espresso          45       3.99   179.55
# 11   Saturday       Latte          35       5.99   209.65
# 12     Sunday    Espresso          45       3.99   179.55
# 13     Sunday       Latte          35       5.99   209.65

# %%
coffee.rename(columns={'new_price': 'price'}, inplace=True)

# %%
coffee = coffee.rename(columns={'new_price': 'price'})

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso          25   3.99    99.75
# 1      Monday       Latte          15   5.99    89.85
# 2     Tuesday    Espresso          30   3.99   119.70
# 3     Tuesday       Latte          20   5.99   119.80
# 4   Wednesday    Espresso          35   3.99   139.65
# 5   Wednesday       Latte          25   5.99   149.75
# 6    Thursday    Espresso          40   3.99   159.60
# 7    Thursday       Latte          30   5.99   179.70
# 8      Friday    Espresso          45   3.99   179.55
# 9      Friday       Latte          35   5.99   209.65
# 10   Saturday    Espresso          45   3.99   179.55
# 11   Saturday       Latte          35   5.99   209.65
# 12     Sunday    Espresso          45   3.99   179.55
# 13     Sunday       Latte          35   5.99   209.65

# %%
bios_new = bios.copy()

# %%
bios_new['first_name'] = bios_new['name'].str.split(' ').str[0]

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios_new.query('first_name == "Harun"')
# Out:
#        athlete_id         name   born_date      born_city    born_region  \
# 59884       60312  Harun Doğan  1976-01-01  Kahramanmaraş  Kahramanmaraş
# 63220       63690  Harun Ülman  1900-07-11            NaN            NaN
#
#       born_country      NOC  height_cm  weight_kg   died_date first_name
# 59884          TUR  Türkiye      165.0       58.0         NaN      Harun
# 63220          NaN  Türkiye        NaN        NaN  1977-01-26      Harun

# %%
bios_new['born_datetime'] = pd.to_datetime(bios_new['born_date'])

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios_new['born_year'] = bios_new['born_datetime'].dt.year

# %%
bios_new[['name', 'born_year']]
# Out:
#                          name  born_year
# 0       Jean-François Blanchy     1886.0
# 1              Arnaud Boetsch     1969.0
# 2                Jean Borotra     1898.0
# 3             Jacques Brugnon     1895.0
# 4                Albert Canet     1878.0
# ...                       ...        ...
# 145495      Polina Luchnikova     2002.0
# 145496    Valeriya Merkusheva     1999.0
# 145497        Yuliya Smirnova     1998.0
# 145498         André Foussard     1899.0
# 145499          Bill Phillips     1913.0
#
# [145500 rows x 2 columns]

# %%
bios_new.to_csv('/bios_new.csv', index = False)

# %%
bios_new['height_category'] = bios_new['height_cm'].apply(lambda x: 'Short' if x < 165 else ('Average' if x < 185 else 'Tall') )

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
def categorize_athlete(row):
  if row['height_cm'] < 175 and row['weight_kg'] < 70:
    return 'Lightweight'
  elif row['height_cm'] < 185 and row['weight_kg'] <= 80:
    return 'Middleweight'
  else:
    return 'Heavyweight'


bios_new['category'] = bios_new.apply(categorize_athlete, axis=1)

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
nocs = pd.read_csv('/noc_regions.csv')

# %%
nocs
# Out:
#      NOC       region                 notes
# 0    AFG  Afghanistan                   NaN
# 1    AHO      Curacao  Netherlands Antilles
# 2    ALB      Albania                   NaN
# 3    ALG      Algeria                   NaN
# 4    AND      Andorra                   NaN
# ..   ...          ...                   ...
# 225  YEM        Yemen                   NaN
# 226  YMD        Yemen           South Yemen
# 227  YUG       Serbia            Yugoslavia
# 228  ZAM       Zambia                   NaN
# 229  ZIM     Zimbabwe                   NaN
#
# [230 rows x 3 columns]

# %%
bios_new = pd.merge(bios, nocs, left_on='born_country', right_on='NOC', how='left')

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country      NOC_x  height_cm  weight_kg  \
# ...

# %%
bios_new.rename(columns={'region': 'born_full_country'}, inplace=True)

# %%
bios_new
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country      NOC_x  height_cm  weight_kg  \
# ...

# %%
bios_new.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country   NOC_x  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date NOC_y born_full_country notes
# 0  1960-10-02   FRA            France   NaN
# 1         NaN   FRA            France   NaN
# 2  1994-07-17   FRA            France   NaN
# ...

# %%
bios_new[bios_new['NOC_x'] != bios_new['born_full_country']][['name', 'NOC_x', 'born_full_country']]
# Out:
#                        name    NOC_x born_full_country
# 4              Albert Canet   France                UK
# 12                J. Defert   France               NaN
# 13           Étienne Durand   France               NaN
# 16               Guy Forget   France           Morocco
# 27       Guy, Baron Lejeune   France               NaN
# ...                     ...      ...               ...
# 145491        Matthew Wepke  Jamaica               NaN
# 145493   Landysh Falyakhova      ROC            Russia
# 145495    Polina Luchnikova      ROC            Russia
# 145496  Valeriya Merkusheva      ROC            Russia
# 145497      Yuliya Smirnova      ROC            Russia
#
# [73210 rows x 3 columns]

# %%
usa = bios_new[bios_new['born_country'] == 'USA'].copy()

# %%
gbr = bios_new[bios_new['born_country'] == 'GBR'].copy()

# %%
usa.head()
# Out:
#       athlete_id               name   born_date         born_city born_region  \
# 54            55      Monique Javer  1967-07-22        Burlingame  California
# 960          964   Xóchitl Escobedo  1968-09-17       West Covina  California
# 961          965  Angélica Gavaldón  1973-10-03         El Centro  California
# 1231        1238     Bert Schneider  1897-07-01         Cleveland        Ohio
# 1345        1352         Laura Berg  1975-01-06  Santa Fe Springs  California
#
#      born_country          NOC_x  height_cm  weight_kg   died_date NOC_y  \
# 54            USA  Great Britain      177.0       64.0         NaN   USA
# 960           USA         Mexico      170.0       60.0         NaN   USA
# 961           USA         Mexico      160.0       54.0         NaN   USA
# 1231          USA         Canada        NaN        NaN  1986-02-20   USA
# 1345          USA  United States      168.0       61.0         NaN   USA
#
#      born_full_country notes
# ...

# %%
gbr.head()
# Out:
#     athlete_id               name   born_date    born_city born_region  \
# 4            5       Albert Canet  1878-04-17   Wandsworth     England
# 37          38    Helen Aitchison  1881-12-06   Sunderland     England
# 38          39  Geraldine Beamish  1883-06-23  Forest Gate     England
# 39          40       Dora Boothby  1881-08-02     Finchley     England
# 40          41     Julie Bradbury  1967-02-12       Oxford     England
#
#    born_country          NOC_x  height_cm  weight_kg   died_date NOC_y  \
# 4           GBR         France        NaN        NaN  1930-07-25   GBR
# 37          GBR  Great Britain        NaN        NaN  1947-05-26   GBR
# 38          GBR  Great Britain        NaN        NaN  1972-05-10   GBR
# 39          GBR  Great Britain        NaN        NaN  1970-02-22   GBR
# 40          GBR  Great Britain      175.0       64.0         NaN   GBR
#
#    born_full_country notes
# 4                 UK   NaN
# 37                UK   NaN
# ...

# %%
new_df = pd.concat([usa, gbr])

# %%
new_df.head()
# Out:
#       athlete_id               name   born_date         born_city born_region  \
# 54            55      Monique Javer  1967-07-22        Burlingame  California
# 960          964   Xóchitl Escobedo  1968-09-17       West Covina  California
# 961          965  Angélica Gavaldón  1973-10-03         El Centro  California
# 1231        1238     Bert Schneider  1897-07-01         Cleveland        Ohio
# 1345        1352         Laura Berg  1975-01-06  Santa Fe Springs  California
#
#      born_country          NOC_x  height_cm  weight_kg   died_date NOC_y  \
# 54            USA  Great Britain      177.0       64.0         NaN   USA
# 960           USA         Mexico      170.0       60.0         NaN   USA
# 961           USA         Mexico      160.0       54.0         NaN   USA
# 1231          USA         Canada        NaN        NaN  1986-02-20   USA
# 1345          USA  United States      168.0       61.0         NaN   USA
#
#      born_full_country notes
# ...

# %%
results
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                    None        Slalom, Women (Olympic)
#
# ...

# %%
combined_df = pd.merge(results, bios, on="athlete_id", how='left')

# %%
combined_df
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                    None        Slalom, Women (Olympic)
#
# ...

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso          25   3.99    99.75
# 1      Monday       Latte          15   5.99    89.85
# 2     Tuesday    Espresso          30   3.99   119.70
# 3     Tuesday       Latte          20   5.99   119.80
# 4   Wednesday    Espresso          35   3.99   139.65
# 5   Wednesday       Latte          25   5.99   149.75
# 6    Thursday    Espresso          40   3.99   159.60
# 7    Thursday       Latte          30   5.99   179.70
# 8      Friday    Espresso          45   3.99   179.55
# 9      Friday       Latte          35   5.99   209.65
# 10   Saturday    Espresso          45   3.99   179.55
# 11   Saturday       Latte          35   5.99   209.65
# 12     Sunday    Espresso          45   3.99   179.55
# 13     Sunday       Latte          35   5.99   209.65

# %%
coffee.loc[0:1, 'Units Sold'] = np.nan

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso         NaN   3.99    99.75
# 1      Monday       Latte         NaN   5.99    89.85
# 2     Tuesday    Espresso         NaN   3.99   119.70
# 3     Tuesday       Latte        20.0   5.99   119.80
# 4   Wednesday    Espresso        35.0   3.99   139.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0   3.99   179.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %%
coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   10 non-null     float64
#  3   price        14 non-null     float64
#  4   revenue      14 non-null     float64
# dtypes: float64(3), object(2)
# memory usage: 692.0+ bytes

# %%
coffee.isna().sum()
# Out:
# Day            0
# Coffee Type    0
# Units Sold     4
# price          0
# revenue        0
# dtype: int64

# %%
coffee.fillna(1000)
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso      1000.0   3.99    99.75
# 1      Monday       Latte      1000.0   5.99    89.85
# 2     Tuesday    Espresso      1000.0   3.99   119.70
# 3     Tuesday       Latte      1000.0   5.99   119.80
# 4   Wednesday    Espresso        35.0   3.99   139.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0   3.99   179.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %%
coffee.fillna(coffee['Units Sold'].mean())
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso        37.0   3.99    99.75
# 1      Monday       Latte        37.0   5.99    89.85
# 2     Tuesday    Espresso        37.0   3.99   119.70
# 3     Tuesday       Latte        37.0   5.99   119.80
# 4   Wednesday    Espresso        35.0   3.99   139.65
# 5   Wednesday       Latte        25.0   5.99   149.75
# 6    Thursday    Espresso        40.0   3.99   159.60
# 7    Thursday       Latte        30.0   5.99   179.70
# 8      Friday    Espresso        45.0   3.99   179.55
# 9      Friday       Latte        35.0   5.99   209.65
# 10   Saturday    Espresso        45.0   3.99   179.55
# 11   Saturday       Latte        35.0   5.99   209.65
# 12     Sunday    Espresso        45.0   3.99   179.55
# 13     Sunday       Latte        35.0   5.99   209.65

# %%
# coffee.loc[[2, 3], 'Units Sold'] = np.nan

# %%
coffee.loc[0:1, ['Units Sold']] = 15

# %%
# coffee['Units Sold'] = coffee['Units Sold'].interpolate()

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso   15.000000   3.99    99.75
# 1      Monday       Latte   15.000000   5.99    89.85
# 2     Tuesday    Espresso   21.666667   3.99   119.70
# 3     Tuesday       Latte   28.333333   5.99   119.80
# 4   Wednesday    Espresso   35.000000   3.99   139.65
# 5   Wednesday       Latte   25.000000   5.99   149.75
# 6    Thursday    Espresso   40.000000   3.99   159.60
# 7    Thursday       Latte   30.000000   5.99   179.70
# 8      Friday    Espresso   45.000000   3.99   179.55
# 9      Friday       Latte   35.000000   5.99   209.65
# 10   Saturday    Espresso   45.000000   3.99   179.55
# 11   Saturday       Latte   35.000000   5.99   209.65
# 12     Sunday    Espresso   45.000000   3.99   179.55
# 13     Sunday       Latte   35.000000   5.99   209.65

# %%
coffee[coffee['Units Sold'].notna()]
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso   15.000000   3.99    99.75
# 1      Monday       Latte   15.000000   5.99    89.85
# 2     Tuesday    Espresso   21.666667   3.99   119.70
# 3     Tuesday       Latte   28.333333   5.99   119.80
# 4   Wednesday    Espresso   35.000000   3.99   139.65
# 5   Wednesday       Latte   25.000000   5.99   149.75
# 6    Thursday    Espresso   40.000000   3.99   159.60
# 7    Thursday       Latte   30.000000   5.99   179.70
# 8      Friday    Espresso   45.000000   3.99   179.55
# 9      Friday       Latte   35.000000   5.99   209.65
# 10   Saturday    Espresso   45.000000   3.99   179.55
# 11   Saturday       Latte   35.000000   5.99   209.65
# 12     Sunday    Espresso   45.000000   3.99   179.55
# 13     Sunday       Latte   35.000000   5.99   209.65

# %%
coffee[coffee['Units Sold'].isna()]
# Out:
# Empty DataFrame
# Columns: [Day, Coffee Type, Units Sold, price, revenue]
# Index: []

# %%
coffee.dropna()
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso   15.000000   3.99    99.75
# 1      Monday       Latte   15.000000   5.99    89.85
# 2     Tuesday    Espresso   21.666667   3.99   119.70
# 3     Tuesday       Latte   28.333333   5.99   119.80
# 4   Wednesday    Espresso   35.000000   3.99   139.65
# 5   Wednesday       Latte   25.000000   5.99   149.75
# 6    Thursday    Espresso   40.000000   3.99   159.60
# 7    Thursday       Latte   30.000000   5.99   179.70
# 8      Friday    Espresso   45.000000   3.99   179.55
# 9      Friday       Latte   35.000000   5.99   209.65
# 10   Saturday    Espresso   45.000000   3.99   179.55
# 11   Saturday       Latte   35.000000   5.99   209.65
# 12     Sunday    Espresso   45.000000   3.99   179.55
# 13     Sunday       Latte   35.000000   5.99   209.65

# %%
bios['born_city'].value_counts()
# Out:
# born_city
# Budapest           1378
# Moskva (Moscow)     883
# Oslo                708
# Stockholm           629
# Praha (Prague)      600
#                    ...
# Bodrogkisfalud        1
# Ternberg              1
# Klaus                 1
# Plaški                1
# Dulwich Hill          1
# Name: count, Length: 22368, dtype: int64

# %%
bios[bios['born_country'] == 'USA']['born_region'].value_counts()
# Out:
# born_region
# California              1634
# New York                 990
# Illinois                 585
# Pennsylvania             530
# Massachusetts            530
# New Jersey               381
# Texas                    368
# Minnesota                365
# Ohio                     328
# Michigan                 319
# Washington               240
# Florida                  235
# Wisconsin                209
# Colorado                 207
# Connecticut              156
# Indiana                  150
# Oregon                   132
# Georgia                  129
# Virginia                 121
# Maryland                 117
# District of Columbia     107
# Iowa                     102
# Hawaiʻi                   95
# Kansas                    94
# Oklahoma                  93
# Louisiana                 92
# Utah                      91
# Missouri                  91
# North Carolina            86
# Arizona                   83
# New Hampshire             83
# ...

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso   15.000000   3.99    99.75
# 1      Monday       Latte   15.000000   5.99    89.85
# 2     Tuesday    Espresso   21.666667   3.99   119.70
# 3     Tuesday       Latte   28.333333   5.99   119.80
# 4   Wednesday    Espresso   35.000000   3.99   139.65
# 5   Wednesday       Latte   25.000000   5.99   149.75
# 6    Thursday    Espresso   40.000000   3.99   159.60
# 7    Thursday       Latte   30.000000   5.99   179.70
# 8      Friday    Espresso   45.000000   3.99   179.55
# 9      Friday       Latte   35.000000   5.99   209.65
# 10   Saturday    Espresso   45.000000   3.99   179.55
# 11   Saturday       Latte   35.000000   5.99   209.65
# 12     Sunday    Espresso   45.000000   3.99   179.55
# 13     Sunday       Latte   35.000000   5.99   209.65

# %%
# coffee.rename(columns={'new_price': 'price'})

# %%
coffee.groupby(['Coffee Type']).agg({'Units Sold': 'sum', 'price':'mean'})
# Out:
#              Units Sold  price
# Coffee Type
# Espresso     246.666667   3.99
# Latte        203.333333   5.99

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue
# 0      Monday    Espresso   15.000000   3.99    99.75
# 1      Monday       Latte   15.000000   5.99    89.85
# 2     Tuesday    Espresso   21.666667   3.99   119.70
# 3     Tuesday       Latte   28.333333   5.99   119.80
# 4   Wednesday    Espresso   35.000000   3.99   139.65
# 5   Wednesday       Latte   25.000000   5.99   149.75
# 6    Thursday    Espresso   40.000000   3.99   159.60
# 7    Thursday       Latte   30.000000   5.99   179.70
# 8      Friday    Espresso   45.000000   3.99   179.55
# 9      Friday       Latte   35.000000   5.99   209.65
# 10   Saturday    Espresso   45.000000   3.99   179.55
# 11   Saturday       Latte   35.000000   5.99   209.65
# 12     Sunday    Espresso   45.000000   3.99   179.55
# 13     Sunday       Latte   35.000000   5.99   209.65

# %%
pivot = coffee.pivot(columns = 'Coffee Type', index='Day', values='revenue')

# %%
pivot
# Out:
# Coffee Type  Espresso   Latte
# Day
# Friday         179.55  209.65
# Monday          99.75   89.85
# Saturday       179.55  209.65
# Sunday         179.55  209.65
# Thursday       159.60  179.70
# Tuesday        119.70  119.80
# Wednesday      139.65  149.75

# %%
pivot.sum()
# Out:
# Coffee Type
# Espresso    1057.35
# Latte       1168.05
# dtype: float64

# %%
pivot.loc['Monday', 'Latte']
# Out:
# 89.85000000000001

# %%
pivot.sum(axis=1)
# Out:
# Day
# Friday       389.2
# Monday       189.6
# Saturday     389.2
# Sunday       389.2
# Thursday     339.3
# Tuesday      239.5
# Wednesday    289.4
# dtype: float64

# %%
bios['born_date'] = pd.to_datetime(bios['born_date'])

# %%
bios['born_date']
# Out:
# 0        1886-12-12
# 1        1969-04-01
# 2        1898-08-13
# 3        1895-05-11
# 4        1878-04-17
#             ...
# 145495   2002-01-30
# 145496   1999-09-20
# 145497   1998-05-08
# 145498   1899-05-19
# 145499   1913-07-15
# Name: born_date, Length: 145500, dtype: datetime64[ns]

# %%
bios.groupby(bios['born_date'].dt.year).count()
# Out:
#            athlete_id  name  born_date  born_city  born_region  born_country  \
# born_date
# 1828.0              1     1          1          1            1             1
# 1831.0              2     2          2          2            2             2
# 1833.0              1     1          1          1            1             1
# 1836.0              1     1          1          1            1             1
# 1837.0              1     1          1          1            1             1
# ...               ...   ...        ...        ...          ...           ...
# 2005.0            163   163        163         64           64            64
# 2006.0             17    17         17          8            8             8
# 2007.0              3     3          3          1            1             1
# 2008.0              3     3          3          2            2             2
# 2009.0              1     1          1          1            1             1
#
# ...

# %%
bios.groupby(bios['born_date'].dt.year)['name'].count().reset_index().sort_values('name', ascending=False)
# Out:
#      born_date  name
# 139     1972.0  2231
# 152     1985.0  2227
# 140     1973.0  2216
# 138     1971.0  2205
# 137     1970.0  2174
# ..         ...   ...
# 5       1838.0     1
# 4       1837.0     1
# 3       1836.0     1
# 2       1833.0     1
# 176     2009.0     1
#
# [177 rows x 2 columns]

# %%
bios['month_born'] = bios['born_date'].dt.month

# %%
bios['year_born'] = bios['born_date'].dt.year

# %%
bios.groupby([bios['year_born'], bios['month_born']])['name'].count().reset_index().sort_values('name', ascending=False)
# Out:
#       year_born  month_born  name
# 1437     1970.0         1.0   239
# 1461     1972.0         1.0   229
# 1629     1986.0         1.0   227
# 1497     1975.0         1.0   227
# 1617     1985.0         1.0   225
# ...         ...         ...   ...
# 95       1857.0         5.0     1
# 96       1857.0         7.0     1
# 97       1857.0         8.0     1
# 98       1857.0         9.0     1
# 1884     2009.0         1.0     1
#
# [1885 rows x 3 columns]

# %%
bios['height_rank'] = bios['height_cm'].rank(ascending=False)

# %%
bios
# Out:
#         athlete_id                   name  born_date        born_city  \
# 0                1  Jean-François Blanchy 1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch 1969-04-01           Meulan
# 2                3           Jean Borotra 1898-08-13         Biarritz
# 3                4        Jacques Brugnon 1895-05-11      Paris VIIIe
# 4                5           Albert Canet 1878-04-17       Wandsworth
# ...            ...                    ...        ...              ...
# 145495      149222      Polina Luchnikova 2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva 1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova 1998-05-08           Kotlas
# 145498      149225         André Foussard 1899-05-19            Niort
# 145499      149814          Bill Phillips 1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
bios.sort_values(['height_rank']).sample(10)[['name','height_rank']]
# Out:
#                       name  height_rank
# 73394       Ifeoma Mbanugo      81027.5
# 18072            John Rahm          NaN
# 104386        Corinne Raux      94490.0
# 114582        Serhiy Breus       6946.0
# 51942          Andrea Heim      58380.5
# 115498      Valeriya Yegay      89274.5
# 47845        József Katona      54014.0
# 50271       Hakan Eskioğlu       9882.0
# 94834         Petsch Moser       9882.0
# 106946  Aleksey Krupnyakov      54014.0

# %%
coffee.head()
# Out:
#          Day Coffee Type  Units Sold  price  revenue
# 0     Monday    Espresso   15.000000   3.99    99.75
# 1     Monday       Latte   15.000000   5.99    89.85
# 2    Tuesday    Espresso   21.666667   3.99   119.70
# 3    Tuesday       Latte   28.333333   5.99   119.80
# 4  Wednesday    Espresso   35.000000   3.99   139.65

# %%
coffee['cum_revenue'] = coffee['revenue'].cumsum()

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue  cum_revenue
# 0      Monday    Espresso   15.000000   3.99    99.75        99.75
# 1      Monday       Latte   15.000000   5.99    89.85       189.60
# 2     Tuesday    Espresso   21.666667   3.99   119.70       309.30
# 3     Tuesday       Latte   28.333333   5.99   119.80       429.10
# 4   Wednesday    Espresso   35.000000   3.99   139.65       568.75
# 5   Wednesday       Latte   25.000000   5.99   149.75       718.50
# 6    Thursday    Espresso   40.000000   3.99   159.60       878.10
# 7    Thursday       Latte   30.000000   5.99   179.70      1057.80
# 8      Friday    Espresso   45.000000   3.99   179.55      1237.35
# 9      Friday       Latte   35.000000   5.99   209.65      1447.00
# 10   Saturday    Espresso   45.000000   3.99   179.55      1626.55
# 11   Saturday       Latte   35.000000   5.99   209.65      1836.20
# 12     Sunday    Espresso   45.000000   3.99   179.55      2015.75
# ...

# %%
coffee['yesterday_revenue'] = coffee['revenue'].shift(2)

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue  cum_revenue  \
# 0      Monday    Espresso   15.000000   3.99    99.75        99.75
# 1      Monday       Latte   15.000000   5.99    89.85       189.60
# 2     Tuesday    Espresso   21.666667   3.99   119.70       309.30
# 3     Tuesday       Latte   28.333333   5.99   119.80       429.10
# 4   Wednesday    Espresso   35.000000   3.99   139.65       568.75
# 5   Wednesday       Latte   25.000000   5.99   149.75       718.50
# 6    Thursday    Espresso   40.000000   3.99   159.60       878.10
# 7    Thursday       Latte   30.000000   5.99   179.70      1057.80
# 8      Friday    Espresso   45.000000   3.99   179.55      1237.35
# 9      Friday       Latte   35.000000   5.99   209.65      1447.00
# 10   Saturday    Espresso   45.000000   3.99   179.55      1626.55
# 11   Saturday       Latte   35.000000   5.99   209.65      1836.20
# 12     Sunday    Espresso   45.000000   3.99   179.55      2015.75
# ...

# %%
coffee['per_change'] = coffee['revenue'] / coffee['yesterday_revenue'] * 100

# %%
coffee
# Out:
#           Day Coffee Type  Units Sold  price  revenue  cum_revenue  \
# 0      Monday    Espresso   15.000000   3.99    99.75        99.75
# 1      Monday       Latte   15.000000   5.99    89.85       189.60
# 2     Tuesday    Espresso   21.666667   3.99   119.70       309.30
# 3     Tuesday       Latte   28.333333   5.99   119.80       429.10
# 4   Wednesday    Espresso   35.000000   3.99   139.65       568.75
# 5   Wednesday       Latte   25.000000   5.99   149.75       718.50
# 6    Thursday    Espresso   40.000000   3.99   159.60       878.10
# 7    Thursday       Latte   30.000000   5.99   179.70      1057.80
# 8      Friday    Espresso   45.000000   3.99   179.55      1237.35
# 9      Friday       Latte   35.000000   5.99   209.65      1447.00
# 10   Saturday    Espresso   45.000000   3.99   179.55      1626.55
# 11   Saturday       Latte   35.000000   5.99   209.65      1836.20
# 12     Sunday    Espresso   45.000000   3.99   179.55      2015.75
# ...

# %%
latte = coffee[coffee['Coffee Type'] == 'Latte'].copy()

# %%
latte.head()
# Out:
#          Day Coffee Type  Units Sold  price  revenue  cum_revenue  \
# 1     Monday       Latte   15.000000   5.99    89.85        189.6
# 3    Tuesday       Latte   28.333333   5.99   119.80        429.1
# 5  Wednesday       Latte   25.000000   5.99   149.75        718.5
# 7   Thursday       Latte   30.000000   5.99   179.70       1057.8
# 9     Friday       Latte   35.000000   5.99   209.65       1447.0
#
#    yesterday_revenue  per_change
# 1                NaN         NaN
# 3              89.85  133.333333
# 5             119.80  125.000000
# 7             149.75  120.000000
# 9             179.70  116.666667

# %%
latte['3days'] = latte['Units Sold'].rolling(4).sum()

# %%
latte
# Out:
#           Day Coffee Type  Units Sold  price  revenue  cum_revenue  \
# 1      Monday       Latte   15.000000   5.99    89.85        189.6
# 3     Tuesday       Latte   28.333333   5.99   119.80        429.1
# 5   Wednesday       Latte   25.000000   5.99   149.75        718.5
# 7    Thursday       Latte   30.000000   5.99   179.70       1057.8
# 9      Friday       Latte   35.000000   5.99   209.65       1447.0
# 11   Saturday       Latte   35.000000   5.99   209.65       1836.2
# 13     Sunday       Latte   35.000000   5.99   209.65       2225.4
#
#     yesterday_revenue  per_change       3days
# 1                 NaN         NaN         NaN
# 3               89.85  133.333333         NaN
# 5              119.80  125.000000         NaN
# 7              149.75  120.000000   98.333333
# 9              179.70  116.666667  118.333333
# 11             209.65  100.000000  125.000000
# 13             209.65  100.000000  135.000000

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
result_numpy = pd.read_csv('/results.csv')

# %%
result_arrow = pd.read_csv('/results.csv', engine='pyarrow', dtype_backend='pyarrow')

# %%
result_numpy
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                     NaN        Slalom, Women (Olympic)
#
# ...

# %%
result_arrow
# Out:
#           year    type              discipline                          event  \
# 0       1912.0  Summer                  Tennis         Singles, Men (Olympic)
# 1       1912.0  Summer                  Tennis         Doubles, Men (Olympic)
# 2       1920.0  Summer                  Tennis         Singles, Men (Olympic)
# 3       1920.0  Summer                  Tennis       Doubles, Mixed (Olympic)
# 4       1920.0  Summer                  Tennis         Doubles, Men (Olympic)
# ...        ...     ...                     ...                            ...
# 308403  2022.0  Winter                    Luge         Singles, Men (Olympic)
# 308404  2022.0  Winter  Alpine Skiing (Skiing)        Slalom, Women (Olympic)
# 308405  2022.0  Winter  Alpine Skiing (Skiing)          Team, Mixed (Olympic)
# 308406  2022.0  Winter  Alpine Skiing (Skiing)  Giant Slalom, Women (Olympic)
# 308407  2022.0  Winter                    <NA>        Slalom, Women (Olympic)
#
# ...

# %%
result_numpy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        305807 non-null  float64
#  1   type        305807 non-null  object
#  2   discipline  308407 non-null  object
#  3   event       308408 non-null  object
#  4   as          308408 non-null  object
#  5   athlete_id  308408 non-null  int64
#  6   noc         308407 non-null  object
#  7   team        121714 non-null  object
#  8   place       283193 non-null  float64
#  9   tied        308408 non-null  bool
#  10  medal       44139 non-null   object
# dtypes: bool(1), float64(2), int64(1), object(7)
# memory usage: 23.8+ MB

# %%
result_arrow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308408 entries, 0 to 308407
# Data columns (total 11 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   year        305807 non-null  double[pyarrow]
#  1   type        305807 non-null  string[pyarrow]
#  2   discipline  308407 non-null  string[pyarrow]
#  3   event       308408 non-null  string[pyarrow]
#  4   as          308408 non-null  string[pyarrow]
#  5   athlete_id  308408 non-null  int64[pyarrow]
#  6   noc         308407 non-null  string[pyarrow]
#  7   team        121714 non-null  string[pyarrow]
#  8   place       283193 non-null  double[pyarrow]
#  9   tied        308408 non-null  bool[pyarrow]
#  10  medal       44139 non-null   string[pyarrow]
# dtypes: bool[pyarrow](1), double[pyarrow](2), int64[pyarrow](1), string[pyarrow](7)
# memory usage: 37.5 MB
